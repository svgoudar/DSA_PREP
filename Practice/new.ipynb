# %% [markdown]
# Here’s a curated list of **10 Easy, 10 Medium, and 10 Hard** DSA problems for each of the specified techniques, ideal for interview prep.
#
# ---
#
# ### 🔹 **Two Pointers**
#
# **Easy**
#
# 1. [Two Sum II – Input Array Is Sorted](https://leetcode.com/problems/two-sum-ii-input-array-is-sorted/)
# 2. [Valid Palindrome](https://leetcode.com/problems/valid-palindrome/)
# 3. [Remove Duplicates from Sorted Array](https://leetcode.com/problems/remove-duplicates-from-sorted-array/)
# 4. [Merge Sorted Array](https://leetcode.com/problems/merge-sorted-array/)
# 5. [Move Zeroes](https://leetcode.com/problems/move-zeroes/)
# 6. [Reverse String](https://leetcode.com/problems/reverse-string/)
# 7. [Intersection of Two Arrays II](https://leetcode.com/problems/intersection-of-two-arrays-ii/)
# 8. [Squares of a Sorted Array](https://leetcode.com/problems/squares-of-a-sorted-array/)
# 9. [Reverse Only Letters](https://leetcode.com/problems/reverse-only-letters/)
# 10. [Check If Every Row and Column Contains All Numbers](https://leetcode.com/problems/check-if-every-row-and-column-contains-all-numbers/)
#
# **Medium**
#
# 1. [3Sum](https://leetcode.com/problems/3sum/)
# 2. [Container With Most Water](https://leetcode.com/problems/container-with-most-water/)
# 3. [Sort Colors](https://leetcode.com/problems/sort-colors/)
# 4. [Minimum Size Subarray Sum](https://leetcode.com/problems/minimum-size-subarray-sum/)
# 5. [Sum of Square Numbers](https://leetcode.com/problems/sum-of-square-numbers/)
# 6. [Next Permutation](https://leetcode.com/problems/next-permutation/)
# 7. [Trapping Rain Water II (2D)](https://leetcode.com/problems/trapping-rain-water-ii/)
# 8. [Boat to Save People](https://leetcode.com/problems/boats-to-save-people/)
# 9. [Longest Turbulent Subarray](https://leetcode.com/problems/longest-turbulent-subarray/)
# 10. [Reorder Data in Log Files](https://leetcode.com/problems/reorder-data-in-log-files/)
#
# **Hard**
#
# 1. [Trapping Rain Water](https://leetcode.com/problems/trapping-rain-water/)
# 2. [Longest Subarray of 1’s After Deleting One Element](https://leetcode.com/problems/longest-subarray-of-1s-after-deleting-one-element/)
# 3. [Palindrome Partitioning II](https://leetcode.com/problems/palindrome-partitioning-ii/)
# 4. [Substring with Concatenation of All Words](https://leetcode.com/problems/substring-with-concatenation-of-all-words/)
# 5. [Minimum Window Subsequence](https://leetcode.com/problems/minimum-window-subsequence/)
# 6. [Minimum Speed to Arrive on Time](https://leetcode.com/problems/minimum-speed-to-arrive-on-time/)
# 7. [Shortest Subarray with Sum at Least K](https://leetcode.com/problems/shortest-subarray-with-sum-at-least-k/)
# 8. [Word Subsets](https://leetcode.com/problems/word-subsets/)
# 9. [Split Array with Equal Sum](https://leetcode.com/problems/split-array-with-equal-sum/)
# 10. [Longest Increasing Path in a Matrix](https://leetcode.com/problems/longest-increasing-path-in-a-matrix/)
#
# ---
#
# ### 🔹 **Hashing**
#
# **Easy**
#
# 1. [Two Sum](https://leetcode.com/problems/two-sum/)
# 2. [Valid Anagram](https://leetcode.com/problems/valid-anagram/)
# 3. [Contains Duplicate](https://leetcode.com/problems/contains-duplicate/)
# 4. [Single Number](https://leetcode.com/problems/single-number/)
# 5. [Intersection of Two Arrays](https://leetcode.com/problems/intersection-of-two-arrays/)
# 6. [Happy Number](https://leetcode.com/problems/happy-number/)
# 7. [First Unique Character in a String](https://leetcode.com/problems/first-unique-character-in-a-string/)
# 8. [Isomorphic Strings](https://leetcode.com/problems/isomorphic-strings/)
# 9. [Ransom Note](https://leetcode.com/problems/ransom-note/)
# 10. [Jewels and Stones](https://leetcode.com/problems/jewels-and-stones/)
#
# **Medium**
#
# 1. [Group Anagrams](https://leetcode.com/problems/group-anagrams/)
# 2. [Top K Frequent Words](https://leetcode.com/problems/top-k-frequent-words/)
# 3. [Subarray Sum Equals K](https://leetcode.com/problems/subarray-sum-equals-k/)
# 4. [Longest Consecutive Sequence](https://leetcode.com/problems/longest-consecutive-sequence/)
# 5. [Copy List with Random Pointer](https://leetcode.com/problems/copy-list-with-random-pointer/)
# 6. [Word Pattern](https://leetcode.com/problems/word-pattern/)
# 7. [Find All Anagrams in a String](https://leetcode.com/problems/find-all-anagrams-in-a-string/)
# 8. [Longest Palindrome](https://leetcode.com/problems/longest-palindrome/)
# 9. [Is Subsequence](https://leetcode.com/problems/is-subsequence/) *(also two‑pointers)*
# 10. [Subdomain Visit Count](https://leetcode.com/problems/subdomain-visit-count/)
#
# **Hard**
#
# 1. [Minimum Window Substring](https://leetcode.com/problems/minimum-window-substring/)
# 2. [Substring with Concatenation of All Words](https://leetcode.com/problems/substring-with-concatenation-of-all-words/)
# 3. [Word Ladder II](https://leetcode.com/problems/word-ladder-ii/)
# 4. [Alien Dictionary](https://leetcode.com/problems/alien-dictionary/)
# 5. [Longest Valid Parentheses](https://leetcode.com/problems/longest-valid-parentheses/) *(hash+stack)*
# 6. [Palindrome Pairs](https://leetcode.com/problems/palindrome-pairs/)
# 7. [Design Twitter](https://leetcode.com/problems/design-twitter/)
# 8. [LRU Cache](https://leetcode.com/problems/lru-cache/)
# 9. [Valid Word Abbreviation](https://leetcode.com/problems/valid-word-abbreviation/)
# 10. [Distinct Subsequences](https://leetcode.com/problems/distinct-subsequences/)
#
# ---
#
# ### 🔹 **Sliding Window**
#
# **Easy**
#
# 1. [Maximum Average Subarray I](https://leetcode.com/problems/maximum-average-subarray-i/)
# 2. [Fruit Into Baskets](https://leetcode.com/problems/fruit-into-baskets/)
# 3. [Sliding Window Maximum (simpler)](https://leetcode.com/problems/sliding-window-maximum/)
# 4. [Number of Substrings with Only 1s](https://leetcode.com/problems/number-of-substrings-with-only-1s/)
# 5. [Valid Parentheses Substring length tracking](https://leetcode.com/problems/valid-parentheses/)
# 6. [Longest Continuous Increasing Subsequence](https://leetcode.com/problems/longest-continuous-increasing-subsequence/)
# 7. [Longest Substring with At Most Two Distinct Characters](https://leetcode.com/problems/longest-substring-with-at-most-two-distinct-characters/)
# 8. [Longest Repeating Character Replacement](https://leetcode.com/problems/longest-repeating-character-replacement/)
# 9. [Minimum Size Subarray Sum](https://leetcode.com/problems/minimum-size-subarray-sum/)
# 10. [Replace the Substring for Balanced String](https://leetcode.com/problems/replace-the-substring-for-balanced-string/)
#
# **Medium**
#
# 1. [Longest Substring Without Repeating Characters](https://leetcode.com/problems/longest-substring-without-repeating-characters/)
# 2. [Find All Anagrams in a String](https://leetcode.com/problems/find-all-anagrams-in-a-string/)
# 3. [Minimum Window Substring](https://leetcode.com/problems/minimum-window-substring/)
# 4. [Subarray Product Less Than K](https://leetcode.com/problems/subarray-product-less-than-k/)
# 5. [Longest Repeating Character Replacement](https://leetcode.com/problems/longest-repeating-character-replacement/)
# 6. [Fruit Into Baskets](https://leetcode.com/problems/fruit-into-baskets/) *(touches medium-level constraints)*
# 7. [Longest Substring with At Most K Distinct Characters](https://leetcode.com/problems/longest-substring-with-at-most-k-distinct-characters/)
# 8. [Smallest Subarray with Sum at Least K](https://leetcode.com/problems/smallest-subarray-with-sum-at-least-k/)
# 9. [Permutation in String](https://leetcode.com/problems/permutation-in-string/)
# 10. [Longest Nice Substring](https://leetcode.com/problems/longest-nice-substring/)
#
# **Hard**
#
# 1. [Longest Substring with At Most Two Distinct Characters](https://leetcode.com/problems/longest-substring-with-at-most-two-distinct-characters/) *(at scale)*
# 2. [Minimum Window Subsequence](https://leetcode.com/problems/minimum-window-subsequence/)
# 3. [Substring with Concatenation of All Words](https://leetcode.com/problems/substring-with-concatenation-of-all-words/)
# 4. [Sliding Window Maximum](https://leetcode.com/problems/sliding-window-maximum/) *(use deque)*
# 5. [Shortest Subarray with Sum at Least K](https://leetcode.com/problems/shortest-subarray-with-sum-at-least-k/)
# 6. [Minimum Window Subarray of Size K](https://leetcode.com/problems/minimum-window-subarray-size-k/)
# 7. [Max Consecutive Ones III](https://leetcode.com/problems/max-consecutive-ones-iii/)
# 8. [Subarrays with K Different Integers](https://leetcode.com/problems/subarrays-with-k-different-integers/)
# 9. [Longest Subarray of 1’s After Deleting One Element](https://leetcode.com/problems/longest-subarray-of-1s-after-deleting-one-element/)
# 10. [Reshape the Matrix to Contiguous Blocks Substring Recognition](https://leetcode.com/problems/reshape-the-matrix-to-contiguous-blocks-substring-recognition/)
#
# ---
#
# ### 🔹 **Two Pointers + Prefix Sum**
#
# **Easy**
#
# 1. [Two Sum II – Input Array Is Sorted](https://leetcode.com/problems/two-sum-ii-input-array-is-sorted/)
# 2. [Sorted Squares of a Sorted Array](https://leetcode.com/problems/squares-of-a-sorted-array/)
# 3. [Subarray Sum Equals K (small array)](https://leetcode.com/problems/subarray-sum-equals-k/)
# 4. [Intersection of Two Arrays II](https://leetcode.com/problems/intersection-of-two-arrays-ii/)
# 5. [How Many Numbers Are Smaller Than the Current Number](https://leetcode.com/problems/how-many-numbers-are-smaller-than-the-current-number/)
# 6. [Richest Customer Wealth – prefix sums trivial](https://leetcode.com/problems/richest-customer-wealth/)
# 7. [Quickest Way to Lose a Sum – sum two pointers](https://leetcode.com/problems/quickest-way-to-lose-a-sum/)
# 8. [Subarray Product Less Than K](https://leetcode.com/problems/subarray-product-less-than-k/)
# 9. [Smallest Subarray with Product at Least K](https://leetcode.com/problems/smallest-subarray-with-product-at-least-k/)
# 10. [Valid Mountain Array (prefix sums for boundaries)](https://leetcode.com/problems/valid-mountain-array/)
#
# **Medium**
#
# 1. [Subarray Sum Equals K](https://leetcode.com/problems/subarray-sum-equals-k/)
# 2. [Minimum Size Subarray Sum](https://leetcode.com/problems/minimum-size-subarray-sum/)
# 3. [Subarrays with K Different Integers](https://leetcode.com/problems/subarrays-with-k-different-integers/)
# 4. [3Sum Smaller](https://leetcode.com/problems/3sum-smaller/)
# 5. [Count Number of Nice Subarrays](https://leetcode.com/problems/count-number-of-nice-subarrays/)
# 6. [Total Fruit](https://leetcode.com/problems/fruit-into-baskets/)
# 7. [Minimum Moves to Equal Array Elements II](https://leetcode.com/problems/minimum-moves-to-equal-array-elements-ii/)
# 8. [Longest Subarray With Sum Divisible by K](https://leetcode.com/problems/longest-subarray-with-sum-divisible-by-k/)
# 9. [Count Subarrays With Median K](https://leetcode.com/problems/count-subarrays-with-median-k/)
# 10. [Subarrays With K Different Integers](https://leetcode.com/problems/subarrays-with-k-different-integers/)
#
# **Hard**
#
# 1. [Shortest Subarray with Sum at Least K](https://leetcode.com/problems/shortest-subarray-with-sum-at-least-k/)
# 2. [Max Sum of Rectangle No Larger Than K](https://leetcode.com/problems/max-sum-of-rectangle-no-larger-than-k/)
# 3. [Minimum Window Subsequence](https://leetcode.com/problems/minimum-window-subsequence/)
# 4. [Subarray Product Less Than K](https://leetcode.com/problems/subarray-product-less-than-k/) *(scale)*
# 5. [Subarray Sum Equals K with Upper & Lower Bound](https://leetcode.com/problems/subarray-sum-equals-k-ii/)
# 6. [Split Array With Equal Sum](https://leetcode.com/problems/split-array-with-equal-sum/)
# 7. [Number of Subarrays With Bounded Maximum](https://leetcode.com/problems/number-subarrays-with-bounded-maximum/)
# 8. [Beautiful Subarrays](https://leetcode.com/problems/beautiful-subarrays/)
# 9. [Count of Range Sum](https://leetcode.com/problems/count-of-range-sum/)
# 10. [Range Product Except Self](https://leetcode.com/problems/range-product-except-self/)
#
# ---
#
# ### 🔹 **Greedy**
#
# **Easy**
#
# 1. [Assign Cookies](https://leetcode.com/problems/assign-cookies/)
# 2. [Gas Station](https://leetcode.com/problems/gas-station/)
# 3. [Best Time to Buy and Sell Stock II](https://leetcode.com/problems/best-time-to-buy-and-sell-stock-ii/)
# 4. [Jump Game](https://leetcode.com/problems/jump-game/)
# 5. [Lemonade Change](https://leetcode.com/problems/lemonade-change/)
# 6. [Maximum Product of Three Numbers](https://leetcode.com/problems/maximum-product-of-three-numbers/)
# 7. [Walking Robot Simulation](https://leetcode.com/problems/walking-robot-simulation/)
# 8. [Merge Strings Alternately](https://leetcode.com/problems/merge-strings-alternately/)
# 9. [Minimum Number of Steps to Make Two Strings Anagram](https://leetcode.com/problems/minimum-number-of-steps-to-make-two-strings-anagram/)
# 10. [Strong Password Checker II](https://leetcode.com/problems/strong-password-checker-ii/)
#
# **Medium**
#
# 1. [Partition Labels](https://leetcode.com/problems/partition-labels/)
# 2. [Jump Game II](https://leetcode.com/problems/jump-game-ii/)
# 3. [Candy](https://leetcode.com/problems/candy/)
# 4. [Russian Doll Envelopes](https://leetcode.com/problems/russian-doll-envelopes/)
# 5. [Task Scheduler](https://leetcode.com/problems/task-scheduler/)
# 6. [Minimum Number of Arrows to Burst Balloons](https://leetcode.com/problems/minimum-number-of-arrows-to-burst-balloons/)
# 7. [Jump Game VI](https://leetcode.com/problems/jump-game-vi/)
# 8. [Split Array Into Consecutive Subsequences](https://leetcode.com/problems/split-array-into-consecutive-subsequences/)
# 9. [Largest Number](https://leetcode.com/problems/largest-number/)
# 10. [Koko Eating Bananas](https://leetcode.com/problems/koko-eating-bananas/)
#
# **Hard**
#
# 1. [Find the Smallest Divisor Given a Threshold](https://leetcode.com/problems/find-the-smallest-divisor-given-a-threshold/)
# 2. [Allocate Mailboxes](https://leetcode.com/problems/allocate-mailboxes/)
# 3. [Minimum Number of Refueling Stops](https://leetcode.com/problems/minimum-number-of-refueling-stops/)
# 4. [Split Array Largest Sum](https://leetcode.com/problems/split-array-largest-sum/)
# 5. [Aggressive Cows – Spoj or variant](https://www.spoj.com/problems/AGGRCOW/)
# 6. [Minimum Number of Arrows to Burst Balloons](https://leetcode.com/problems/minimum-number-of-arrows-to-burst-balloons/) *(harder constraints)*
# 7. [Split Array into Fibonacci Sequence](https://leetcode.com/problems/split-array-into-fibonacci-sequence/)
# 8. [Maximize Sweetness of Chocolate](https://leetcode.com/problems/maximum-tastiness-of-candy-boxes/)
# 9. [Minimum Cost to Cut a Stick](https://leetcode.com/problems/minimum-cost-to-cut-a-stick/)
# 10. [Valid Word Square](https://leetcode.com/problems/valid-word-square/) *(greedy+backtracking)*
#
# ---
#
# ### 🔹 **Brute Force**
#
# **Easy**
#
# 1. [Valid Palindrome II](https://leetcode.com/problems/valid-palindrome-ii/) *(check all splits)*
# 2. [Intersection of Two Arrays II](https://leetcode.com/problems/intersection-of-two-arrays-ii/)
# 3. [Majority Element](https://leetcode.com/problems/majority-element/) *(count all)*
# 4. [Two Sum](https://leetcode.com/problems/two-sum/) *(brute pair-check)*
# 5. [Reverse String](https://leetcode.com/problems/reverse-string/)
# 6. [Best Time to Buy and Sell Stock](https://leetcode.com/problems/best-time-to-buy-and-sell-stock/) *(check all pairs)*
# 7. [Linked List Cycle II](https://leetcode.com/problems/linked-list-cycle-ii/) *(step pointers)*
# 8. [Palindrome Number](https://leetcode.com/problems/palindrome-number/)
# 9. [Design Phone Directory](https://leetcode.com/problems/design-phone-directory/)
# 10. [Add Strings](https://leetcode.com/problems/add-strings/)
#
# **Medium**
#
# 1. [3Sum](https://leetcode.com/problems/3sum/) *(brute triple loops)*
# 2. [4Sum](https://leetcode.com/problems/4sum/)
# 3. [Word Search](https://leetcode.com/problems/word-search/) *(DFS brute)*
# 4. [Longest Palindromic Substring](https://leetcode.com/problems/longest-palindromic-substring/) *(expand all centers)*
# 5. [Minimum Window Substring](https://leetcode.com/problems/minimum-window-substring/) *(check all substrings)*
# 6. [Combination Sum](https://leetcode.com/problems/combination-sum/) *(try all combos)*
# 7. [Subset Sum](https://leetcode.com/problems/subset-sum/) *(backtracking)*
# 8. [Number of Islands](https://leetcode.com/problems/number-of-islands/) *(BFS/DFS)*
# 9. [Minimum Genetic Mutation](https://leetcode.com/problems/minimum-genetic-mutation/) *(BFS brute)*
# 10. [Permutation in String](https://leetcode.com/problems/permutation-in-string/) *(check each window)*
#
# **Hard**
#
# 1. [Regular Expression Matching](https://leetcode.com/problems/regular-expression-matching/)
# 2. [Palindrome Partitioning II](https://leetcode.com/problems/palindrome-partitioning-ii/)
# 3. [Word Ladder II](https://leetcode.com/problems/word-ladder-ii/)
# 4. [N-Queens II](https://leetcode.com/problems/n-queens-ii/)
# 5. [Sudoku Solver](https://leetcode.com/problems/sudoku-solver/)
# 6. [K-th Smallest Number in Multiplication Table](https://leetcode.com/problems/k-th-smallest-number-in-multiplication-table/)
# 7. [Expression Add Operators](https://leetcode.com/problems/expression-add-operators/)
# 8. [Scramble String](https://leetcode.com/problems/scramble-string/)
# 9. [Merge k Sorted Lists](https://leetcode.com/problems/merge-k-sorted-lists/)
# 10. [Word Break II](https://leetcode.com/problems/word-break-ii/)
#
# ---
#
# ### 🔹 **Divide & Conquer**
#
# **Easy**
#
# 1. [Binary Search](https://leetcode.com/problems/binary-search/)
# 2. [Search Insert Position](https://leetcode.com/problems/search-insert-position/)
# 3. [Pow(x, n)](https://leetcode.com/problems/powx-n/)
# 4. [Merge Two Sorted Lists](https://leetcode.com/problems/merge-two-sorted-lists/)
# 5. [Invert Binary Tree](https://leetcode.com/problems/invert-binary-tree/)
# 6. [Symmetric Tree](https://leetcode.com/problems/symmetric-tree/)
# 7. [Maximum Depth of Binary Tree](https://leetcode.com/problems/maximum-depth-of-binary-tree/)
# 8. [Merge Sorted Array](https://leetcode.com/problems/merge-sorted-array/)
# 9. [Tree Preorder Traversal (recursive)](https://leetcode.com/problems/binary-tree-preorder-traversal/)
# 10. [Quick Sort (implementation practice)](https://leetcode.com/problems/sort-an-array/)
#
# **Medium**
#
# 1. [Merge k Sorted Lists](https://leetcode.com/problems/merge-k-sorted-lists/)
# 2. [Longest Palindromic Substring](https://leetcode.com/problems/longest-palindromic-substring/)
# 3. [Maximum Subarray](https://leetcode.com/problems/maximum-subarray/) *(divide & conquer version)*
# 4. [Number of Islands](https://leetcode.com/problems/number-of-islands/) *(recursive flood fill)*
# 5. [Count of Range Sum](https://leetcode.com/problems/count-of-range-sum/)
# 6. [Search in Rotated Sorted Array](https://leetcode.com/problems/search-in-rotated-sorted-array/)
# 7. [Kth Largest Element in an Array](https://leetcode.com/problems/kth-largest-element-in-an-array/)
# 8. [Lowest Common Ancestor of BST](https://leetcode.com/problems/lowest-common-ancestor-of-a-binary-search-tree/)
# 9. [Construct Binary Tree from Preorder and Inorder Traversal](https://leetcode.com/problems/construct-binary-tree-from-preorder-and-inorder-traversal/)
# 10. [Recover Binary Search Tree](https://leetcode.com/problems/recover-binary-search-tree/)
#
# **Hard**
#
# 1. [Median of Two Sorted Arrays](https://leetcode.com/problems/median-of-two-sorted-arrays/)
# 2. [Serialize and Deserialize Binary Tree](https://leetcode.com/problems/serialize-and-deserialize-binary-tree/)
# 3. [Largest Rectangle in Histogram](https://leetcode.com/problems/largest-rectangle-in-histogram/) *(via D\&C)*
# 4. [Maximum Rectangle](https://leetcode.com/problems/maximal-rectangle/)
# 5. [Word Search II](https://leetcode.com/problems/word-search-ii/)
# 6. [Palindrome Partitioning II](https://leetcode.com/problems/palindrome-partitioning-ii/)
# 7. [Count of Range Sum](https://leetcode.com/problems/count-of-range-sum/)
# 8. [Merge Intervals](https://leetcode.com/problems/merge-intervals/)
# 9. [Trapping Rain Water II](https://leetcode.com/problems/trapping-rain-water-ii/)
# 10. [Super Ugly Number](https://leetcode.com/problems/super-ugly-number/)
#
# ---
#
# Let me know if you'd like the list formatted into a grid, spreadsheet, PDF, or with additional filters by platform or tag!

# %% [markdown]
# Here are **30 Linked‐List–focused DSA problems**, sorted by difficulty (10 easy, 10 medium, 10 hard). Perfect for interview prep or mastering linked list challenges:
#
# ---
#
# ## 🟢 Easy (10)
#
# 1. Reverse a singly linked list
# 2. Merge two sorted linked lists
# 3. Remove N‑th node from end of list
# 4. Delete a node (given direct pointer to node)
# 5. Palindrome linked list (is it the same forward & backward?)
# 6. Remove duplicates from sorted linked list
# 7. Intersection of two linked lists (find common node)
# 8. Linked list cycle detection (Floyd's Tortoise & Hare)
# 9. Delete all nodes that have duplicate numbers (retain only distinct)
# 10. Odd‑even linked list (group odd-indexed and even-indexed nodes)
#
# ---
#
# ## 🟠 Medium (10)
#
# 1. Add two numbers represented by linked lists
# 2. Partition linked list by value x
# 3. Rotate linked list right by k places
# 4. Copy list with random pointer
# 5. Sort a linked list (merge sort)
# 6. Flatten multilevel doubly linked list
# 7. Reverse nodes in k‑group
# 8. Remove nodes such that next node has greater value (keep nodes with no greater node to their right)
# 9. Reorder list: L0→Ln→L1→Ln‑1…
# 10. Split linked list into parts of nearly equal size
#
# ---
#
# ## 🔴 Hard (10)
#
# 1. Merge k sorted linked lists
# 2. Reverse nodes between positions m and n (one‑pass, in‑place)
# 3. Reconstruct binary tree from linked list where each node lists left/right children
# 4. LRU Cache implementation using doubly‑linked list
# 5. Find maximum twin sum of a linked list (first+last)
# 6. Palindrome linked list with O(1) extra space (optimal half‑reverse)
# 7. Add two numbers II (lists not reversed, high‑digit first)
# 8. Copy linked list with random pointer in O(1) space
# 9. Sort linked list in O(n log n) time and O(1) space
# 10. Split linked list into descending sequences (longest piles decomposition)
#
# ---
#
# Looking for **solutions**, **code examples**, or deeper explanations for any? I can also transform one into the `<details>` style with code and complexity—just say which! 🎯
