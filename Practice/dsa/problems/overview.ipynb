# %% [markdown]
# ### 🗂️ DSA Questions topic wise
#
#
# - [Arrays](1.Arrays.ipynb)
# - [Strings](2.Strings.ipynb)
# - [Linked Lists](3.Linked_lists.ipynb)
# - [Stacks](4.Stacks.ipynb)
# - [Queue](5.Queue.ipynb)
# - [Tree Graphs](5a.tree_graphs.ipynb)
# - [Hashing](5b.Hashing.ipynb)
# - [Sorting Algorithms](6.Sorting_algorithm.ipynb)
# - [Searching Algorithms](7.Searching_algorithm.ipynb)
# - [Brute Force](8.brute_force.ipynb)
# - [Divide and Conquer](9.Divide_and_conquer.ipynb)
# - [Greedy](10.greedy.ipynb)
# - [Sliding Window](12.sliding_window.ipynb)
# - [Two Pointers](13.Two_pointers.ipynb)
# - [Prefix Sum & Pointer](14.prefix_sum_and_pointer.ipynb)
# - [Dynamic Programming](15.DP.ipynb)
# - [Backtracking](16.Backtracking.ipynb)
# - [Bit Manipulation](17.Bit_manipulation.ipynb)
#
#
#
# ```{dropdown} Click here for Sections
# ```{tableofcontents}
